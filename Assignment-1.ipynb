# %%
import numpy as np
list1=[1,2,3]
array1=np.array(list1)
print("list =",list1)
print("array =",array1)
# Out:
# list = [1, 2, 3]
# array = [1 2 3]

# %% [markdown]
# # New Section

# %%
a=1
print("type of a=",type(a))
b="ashu"
print("type of b=",type(b))
c=1.2
print("type of c=",type(c))
d=[1,2,3,4]
print("type of d=",type(d))

# %%
import numpy as np
list1=[1,2,3,4]
array1=np.array(list1)
list2=[5,6,7,8]
array2=np.array(list2)
array3=array1+array2
print("Addition of two:",array3)
print("dimension of array3 is",array3.ndim)

# %%
import numpy as np
a=90
print("sin30=",np.sin(a))
b=40
print("log(40)=",np.log(40))
c=1230
print("exp(1230)=",np.exp(40))
list1=[1,2,3,4]
array1=np.array(list1)
print("log of array=",np.log(array1))
print("log of array=",np.log(array1))
print("exp of array=",np.exp(array1))
